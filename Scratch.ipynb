# %%
import JohnDistribution as jd

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
jd.Gaussian(0,1)
# Out:
# N(mu=0, sigma=1)

# %%
test_1 = jd.Gaussian(0,1)

# %%
jd.Cauchy(1,2)
# Out:
# Cauchy Distribution: x_0=2, gamma=1

# %%
test_2 = jd.Cauchy(1,2)

# %%
test_2.plot(0,5,.01)
